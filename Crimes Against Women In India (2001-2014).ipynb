# %% [markdown]
# # Crimes against Women in India (2001-2014)

# %% [markdown]
# From even before the time of her birth a girl could become a victim of a crime.
# The 2012 National Crime Records Bureau report of India states a reported crime rate of 46 per 100,000, rape rate of 2 per 100,000, dowry homicide rate of 0.7 per 100,000 and the rate of domestic cruelty by husband or his relatives as 5.9 per 100,000.
# A 2014 study in the Lancet states, “Whereas an 8·5% prevalence of sexual violence in the country [India] is among the lowest in the world, it is estimated to affect 27·5 million women in India [given India’s large population]. Further, the 2006 survey found that 85% of women who suffered sexual violence, in or outside of marriage, never sought help, and only 1% report it to the police.”
# This data set only covers a small subset of all the crimes comitted against women on a daily basis in the country. The number of cases unreported also means this data is not complete.
# The aim is to analyse it for descriptive trends in the reported cases from all over the country between 2001-2014.
#
# SOURCE: http://www.womenlawsindia.com/legal-awareness/crimes-against-women/

# %% [markdown]
# # OVERALL TRENDS
# # INDIVIDUAL CRIMES
# # STATE WISE

# %% [markdown]
# In this project, we will focus on finding possible answers to the following questions:-
# - Are there any trends in the total number of reported cases from 2001 to 2014?
# - Which states have the highest and lowest number of cases?
# - Based on this data set, which crime is reported the most?
# - Are there any trends in individual states?
#
# Which year had the highest number of Rape cases
# - Which state had the highest rape cases?
# - State wise distributions
# - District wise distributions
# - was there an increase in cases from 2001 to 2014?
# - which district from each state had the highest and whihc year?
# - histogram distribution thing

# %% [markdown]
# Description of the data set
# - all the states data for 2001 followed by all the states data for 2002 and so on
# - total values for each state is given within the year
# - does not contain every single state in the country or every district (look into it)

# %% [markdown]
# Procedure:
# First i got rid of the total values because it was resulting in double counting.
# Created a seperate df for total values and then dropped them from the main df
#
# DAY1: CLEAN THE DATA
# - Main issues with the data set:
# - total values in between the data set (solved)
# - a & n islands and a&n islands despite being the same were counted seperately just like delhi ut and delhi and d&n haveli and d & n haveli (solved)
# - dropping the districts because there are too many too varied and not all districts in the country have been counted

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("Crimes-against-women.csv")

# %%
df
# Out:
#              STATE/UT       DISTRICT  Year  Rape  Kidnapping and Abduction  \
# 0      ANDHRA PRADESH       ADILABAD  2001    50                        30
# 1      ANDHRA PRADESH      ANANTAPUR  2001    23                        30
# 2      ANDHRA PRADESH       CHITTOOR  2001    27                        34
# 3      ANDHRA PRADESH       CUDDAPAH  2001    20                        20
# 4      ANDHRA PRADESH  EAST GODAVARI  2001    23                        26
# ...               ...            ...   ...   ...                       ...
# 10672     Lakshadweep    Lakshadweep  2014     1                         0
# 10673     Lakshadweep          TOTAL  2014     1                         0
# 10674      Puducherry       Karaikal  2014     3                         1
# 10675      Puducherry     Puducherry  2014     7                         6
# 10676      Puducherry          TOTAL  2014    10                         7
#
#        Dowry Deaths  Assault on women with intent to outrage her modesty  \
# 0                16                                                149
# 1                 7                                                118
# 2                14                                                112
# 3                17                                                126
# 4                12                                                109
# ...             ...                                                ...
# 10672             0                                                  1
# 10673             0                                                  1
# 10674             0                                                 12
# 10675             1                                                 20
# 10676             1                                                 32
#
#        Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# 0                              34                                  175
# 1                              24                                  154
# 2                              83                                  186
# 3                              38                                   57
# 4                              58                                  247
# ...                           ...                                  ...
# 10672                           2                                    0
# 10673                           2                                    0
# 10674                           1                                    1
# 10675                           7                                    3
# 10676                           8                                    4
#
#        Importation of Girls
# 0                         0
# 1                         0
# 2                         0
# 3                         0
# 4                         0
# ...                     ...
# 10672                     0
# 10673                     0
# 10674                     0
# 10675                     0
# 10676                     0
#
# [10677 rows x 10 columns]

# %%
df.head()
# Out:
#          STATE/UT       DISTRICT  Year  Rape  Kidnapping and Abduction  \
# 0  ANDHRA PRADESH       ADILABAD  2001    50                        30
# 1  ANDHRA PRADESH      ANANTAPUR  2001    23                        30
# 2  ANDHRA PRADESH       CHITTOOR  2001    27                        34
# 3  ANDHRA PRADESH       CUDDAPAH  2001    20                        20
# 4  ANDHRA PRADESH  EAST GODAVARI  2001    23                        26
#
#    Dowry Deaths  Assault on women with intent to outrage her modesty  \
# 0            16                                                149
# 1             7                                                118
# 2            14                                                112
# 3            17                                                126
# 4            12                                                109
#
#    Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# 0                          34                                  175
# 1                          24                                  154
# 2                          83                                  186
# 3                          38                                   57
# 4                          58                                  247
#
#    Importation of Girls
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0

# %%
df.tail()
# Out:
#           STATE/UT     DISTRICT  Year  Rape  Kidnapping and Abduction  \
# 10672  Lakshadweep  Lakshadweep  2014     1                         0
# 10673  Lakshadweep        TOTAL  2014     1                         0
# 10674   Puducherry     Karaikal  2014     3                         1
# 10675   Puducherry   Puducherry  2014     7                         6
# 10676   Puducherry        TOTAL  2014    10                         7
#
#        Dowry Deaths  Assault on women with intent to outrage her modesty  \
# 10672             0                                                  1
# 10673             0                                                  1
# 10674             0                                                 12
# 10675             1                                                 20
# 10676             1                                                 32
#
#        Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# 10672                           2                                    0
# 10673                           2                                    0
# 10674                           1                                    1
# 10675                           7                                    3
# 10676                           8                                    4
#
#        Importation of Girls
# 10672                     0
# 10673                     0
# 10674                     0
# 10675                     0
# 10676                     0

# %%
df.shape
# Out:
# (10677, 10)

# %%
df.sample(10)
# Out:
#               STATE/UT         DISTRICT  Year  Rape  Kidnapping and Abduction  \
# 1423             DELHI            NORTH  2002    27                        47
# 1092       MAHARASHTRA           NANDED  2002    29                        34
# 2711        TAMIL NADU     CHENNAI RLY.  2004     0                         1
# 914   HIMACHAL PRADESH     LAHAUL-SPITI  2002     0                         0
# 1257        TAMIL NADU        CUDDALORE  2002    27                        36
# 5427            KERALA         THRISSUR  2008    46                        12
# 8545            KERALA         KOTTAYAM  2012    55                        17
# 5792     UTTAR PRADESH  ST.RAVIDASNAGAR  2008     2                         9
# 6898         JHARKHAND           GARHWA  2010    21                        23
# 208    JAMMU & KASHMIR           BORDER  2001    12                        10
#
#       Dowry Deaths  Assault on women with intent to outrage her modesty  \
# 1423             5                                                 31
# 1092            24                                                 83
# 2711             1                                                  0
# 914              0                                                  2
# 1257            10                                                110
# 5427             2                                                214
# 8545             1                                                265
# 5792            11                                                  2
# 6898            10                                                 11
# 208              0                                                 15
#
#       Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# 1423                          23                                    4
# 1092                           6                                  241
# 2711                           2                                    1
# 914                            0                                    0
# 1257                          21                                   27
# 5427                          29                                  332
# 8545                          55                                  255
# 5792                           6                                   16
# 6898                           0                                   38
# 208                            5                                    3
#
#       Importation of Girls
# 1423                     0
# 1092                     0
# 2711                     0
# 914                      0
# 1257                     0
# 5427                     0
# 8545                     0
# 5792                     0
# 6898                     0
# 208                      0

# %%
df.dtypes
# Out:
# STATE/UT                                               object
# DISTRICT                                               object
# Year                                                    int64
# Rape                                                    int64
# Kidnapping and Abduction                                int64
# Dowry Deaths                                            int64
# Assault on women with intent to outrage her modesty     int64
# Insult to modesty of Women                              int64
# Cruelty by Husband or his Relatives                     int64
# Importation of Girls                                    int64
# dtype: object

# %%
df.columns
# Out:
# Index(['STATE/UT', 'DISTRICT', 'Year', 'Rape', 'Kidnapping and Abduction',
#        'Dowry Deaths', 'Assault on women with intent to outrage her modesty',
#        'Insult to modesty of Women', 'Cruelty by Husband or his Relatives',
#        'Importation of Girls'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10677 entries, 0 to 10676
# Data columns (total 10 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   STATE/UT                                             10677 non-null  object
#  1   DISTRICT                                             10677 non-null  object
#  2   Year                                                 10677 non-null  int64
#  3   Rape                                                 10677 non-null  int64
#  4   Kidnapping and Abduction                             10677 non-null  int64
#  5   Dowry Deaths                                         10677 non-null  int64
#  6   Assault on women with intent to outrage her modesty  10677 non-null  int64
#  7   Insult to modesty of Women                           10677 non-null  int64
#  8   Cruelty by Husband or his Relatives                  10677 non-null  int64
#  9   Importation of Girls                                 10677 non-null  int64
# dtypes: int64(8), object(2)
# memory usage: 834.3+ KB

# %% [markdown]
# ### Now we clean the data set

# %% [markdown]
# Start by dealing with inconsistent names of States and Union Territories

# %%
df['STATE/UT']=df['STATE/UT'].str.lower()

# %%
df['STATE/UT'].unique()
# Out:
# array(['andhra pradesh', 'arunachal pradesh', 'assam', 'bihar',
#        'chhattisgarh', 'goa', 'gujarat', 'haryana', 'himachal pradesh',
#        'jammu & kashmir', 'jharkhand', 'karnataka', 'kerala',
#        'madhya pradesh', 'maharashtra', 'manipur', 'meghalaya', 'mizoram',
#        'nagaland', 'odisha', 'punjab', 'rajasthan', 'sikkim',
#        'tamil nadu', 'tripura', 'uttar pradesh', 'uttarakhand',
#        'west bengal', 'a & n islands', 'chandigarh', 'd & n haveli',
#        'daman & diu', 'delhi', 'lakshadweep', 'puducherry', 'a&n islands',
#        'd&n haveli', 'delhi ut', 'telangana'], dtype=object)

# %%
df["STATE/UT"].replace({"delhi ut": "delhi", "a&n islands": "a & n islands", "d&n haveli" :"d & n haveli"}, inplace=True)

# %%
df['STATE/UT'].unique()
# Out:
# array(['andhra pradesh', 'arunachal pradesh', 'assam', 'bihar',
#        'chhattisgarh', 'goa', 'gujarat', 'haryana', 'himachal pradesh',
#        'jammu & kashmir', 'jharkhand', 'karnataka', 'kerala',
#        'madhya pradesh', 'maharashtra', 'manipur', 'meghalaya', 'mizoram',
#        'nagaland', 'odisha', 'punjab', 'rajasthan', 'sikkim',
#        'tamil nadu', 'tripura', 'uttar pradesh', 'uttarakhand',
#        'west bengal', 'a & n islands', 'chandigarh', 'd & n haveli',
#        'daman & diu', 'delhi', 'lakshadweep', 'puducherry', 'telangana'],
#       dtype=object)

# %%
df['STATE/UT'].nunique()
# Out:
# 36

# %% [markdown]
# Ladakh is missing and daman and diu and d and n haveli were combined in 2019

# %%
total_df = df[df.DISTRICT == 'TOTAL']

# %%
total_df
# Out:
#                 STATE/UT DISTRICT  Year  Rape  Kidnapping and Abduction  \
# 28        andhra pradesh    TOTAL  2001   871                       765
# 42     arunachal pradesh    TOTAL  2001    33                        55
# 70                 assam    TOTAL  2001   817                      1070
# 115                bihar    TOTAL  2001   888                       518
# 135         chhattisgarh    TOTAL  2001   959                       171
# ...                  ...      ...   ...   ...                       ...
# 10648       d & n haveli    TOTAL  2014     5                         7
# 10651        daman & diu    TOTAL  2014     2                         1
# 10671              delhi    TOTAL  2014  2096                      4034
# 10673        lakshadweep    TOTAL  2014     1                         0
# 10676         puducherry    TOTAL  2014    10                         7
#
#        Dowry Deaths  Assault on women with intent to outrage her modesty  \
# 28              420                                               3544
# 42                0                                                 78
# 70               59                                                850
# 115             859                                                562
# 135              70                                               1763
# ...             ...                                                ...
# 10648             0                                                  2
# 10651             0                                                  3
# 10671           153                                               4322
# 10673             0                                                  1
# 10676             1                                                 32
#
#        Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# 28                           2271                                 5791
# 42                              3                                   11
# 70                              4                                 1248
# 115                            21                                 1558
# 135                           161                                  840
# ...                           ...                                  ...
# 10648                           1                                    6
# 10651                           0                                    1
# 10671                        1361                                 3173
# 10673                           2                                    0
# 10676                           8                                    4
#
#        Importation of Girls
# 28                        7
# 42                        0
# 70                        0
# 115                      83
# 135                       0
# ...                     ...
# 10648                     0
# 10651                     0
# 10671                     0
# 10673                     0
# 10676                     0
#
# [479 rows x 10 columns]

# %%
total_df.sample(10)
# Out:
#               STATE/UT DISTRICT  Year  Rape  Kidnapping and Abduction  \
# 6577       uttarakhand    TOTAL  2009   111                       247
# 970          jharkhand    TOTAL  2002   797                       178
# 5842      d & n haveli    TOTAL  2008     6                        11
# 5254               goa    TOTAL  2008    30                        28
# 10673      lakshadweep    TOTAL  2014     1                         0
# 10651      daman & diu    TOTAL  2014     2                         1
# 7672   jammu & kashmir    TOTAL  2011   277                      1023
# 9834             delhi    TOTAL  2013  1636                      3609
# 2581           manipur    TOTAL  2004    31                        71
# 715         puducherry    TOTAL  2001     9                         3
#
#        Dowry Deaths  Assault on women with intent to outrage her modesty  \
# 6577             94                                                119
# 970             275                                                411
# 5842              0                                                  4
# 5254              2                                                 32
# 10673             0                                                  1
# 10651             0                                                  3
# 7672             11                                               1194
# 9834            144                                               3515
# 2581              0                                                 30
# 715               1                                                 35
#
#        Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# 6577                          249                                  361
# 970                             3                                  588
# 5842                            0                                    4
# 5254                           12                                   12
# 10673                           2                                    0
# 10651                           0                                    1
# 7672                          350                                  286
# 9834                          916                                 3033
# 2581                            0                                    2
# 715                            27                                    3
#
#        Importation of Girls
# 6577                      0
# 970                      36
# 5842                      0
# 5254                      0
# 10673                     0
# 10651                     0
# 7672                      0
# 9834                      0
# 2581                      0
# 715                       0

# %%
yeartotal_df=total_df.groupby('STATE/UT')[['Rape','Kidnapping and Abduction','Dowry Deaths','Assault on women with intent to outrage her modesty','Insult to modesty of Women','Cruelty by Husband or his Relatives','Importation of Girls']].sum()

# %%
yeartotal_df
# Out:
#                     Rape  Kidnapping and Abduction  Dowry Deaths  \
# STATE/UT
# a & n islands        168                       106            10
# andhra pradesh     16075                     17252          6922
# arunachal pradesh    658                       735             3
# assam              20095                     31037          1634
# bihar              15379                     28543         16103
# chandigarh           385                       841            45
# chhattisgarh       14654                      5904          1379
# d & n haveli          66                       112             1
# daman & diu           30                        22             3
# delhi               3732                      7643           297
# goa                  531                       320            19
# gujarat             5822                     17335           554
# haryana             8555                     10008          3686
# himachal pradesh    2337                      2058            56
# jammu & kashmir     3519                     10582           147
# jharkhand          11413                      7093          3948
# karnataka           7528                      8131          3508
# kerala             10015                      2226           350
# lakshadweep           10                         1             0
# madhya pradesh     45498                     17804         10545
# maharashtra        24487                     15184          4848
# manipur              534                      1303             3
# meghalaya           1321                       335            18
# mizoram             1035                        15             4
# nagaland             281                        95             1
# odisha             15240                     12794          5391
# puducherry           104                       153            28
# punjab              7328                      7548          1762
# rajasthan          22842                     33139          5927
# sikkim               285                        90             2
# tamil nadu          8330                     15454          2530
# telangana            979                       711           289
# tripura             2530                      1101           376
# uttar pradesh      25575                     67953         28628
# uttarakhand         1876                      3242           987
# west bengal        23938                     30579          6154
#
#                    Assault on women with intent to outrage her modesty  \
# STATE/UT
# a & n islands                                                    300
# andhra pradesh                                                 63476
# arunachal pradesh                                                998
# assam                                                          19128
# bihar                                                           8479
# chandigarh                                                       544
# chhattisgarh                                                   23548
# d & n haveli                                                      53
# daman & diu                                                       20
# delhi                                                           7837
# goa                                                              692
# gujarat                                                        11593
# haryana                                                         8571
# himachal pradesh                                                4628
# jammu & kashmir                                                14319
# jharkhand                                                       4949
#
#        Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# 0                              34                                  175
# 1                              24                                  154
# 2                              83                                  186
# 3                              38                                   57
# 4                              58                                  247
# ...                           ...                                  ...
# 10669                           0                                    0
# 10670                          63                                  416
# 10672                           2                                    0
# 10674                           1                                    1
# 10675                           7                                    3
#
#        Importation of Girls
# 0                         0
# 1                         0
# 2                         0
# 3                         0
# 4                         0
# ...                     ...
# 10669                     0
# 10670                     0
# 10672                     0
# 10674                     0
# 10675                     0
#
# [10186 rows x 10 columns]

# %%
df.drop(labels="DISTRICT", axis=1)
# Out:
#              STATE/UT  Year  Rape  Kidnapping and Abduction  Dowry Deaths  \
# 0      andhra pradesh  2001    50                        30            16
# 1      andhra pradesh  2001    23                        30             7
# 2      andhra pradesh  2001    27                        34            14
# 3      andhra pradesh  2001    20                        20            17
# 4      andhra pradesh  2001    23                        26            12
# ...               ...   ...   ...                       ...           ...
# 10669           delhi  2014     0                         0             0
# 10670           delhi  2014   251                       546            13
# 10672     lakshadweep  2014     1                         0             0
# 10674      puducherry  2014     3                         1             0
# 10675      puducherry  2014     7                         6             1
#
#        Assault on women with intent to outrage her modesty  \
# 0                                                    149
# 1                                                    118
# 2                                                    112
# 3                                                    126
# 4                                                    109
# ...                                                  ...
# 10669                                                  0
# 10670                                                484
# 10672                                                  1
# 10674                                                 12
# 10675                                                 20
#
#        Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# 0                              34                                  175
# 1                              24                                  154
# 2                              83                                  186
# 3                              38                                   57
# 4                              58                                  247
# ...                           ...                                  ...
# 10669                           0                                    0
# 10670                          63                                  416
# 10672                           2                                    0
# 10674                           1                                    1
# 10675                           7                                    3
#
#        Importation of Girls
# 0                         0
# 1                         0
# 2                         0
# 3                         0
# 4                         0
# ...                     ...
# 10669                     0
# 10670                     0
# 10672                     0
# 10674                     0
# 10675                     0
#
# [10186 rows x 9 columns]

# %%
#states_df['STATE/UT'] = states_df.index
year_df['Year']= year_df.index

# %% [markdown]
# # Data Analysis:

# %% [markdown]
# # OVERALL ANALYSIS

# %%
arr = year_df.sum(axis=1)
sns.set(rc={'figure.figsize':(12,9)})
ax=plt.axes()

plt.xticks(fontweight='bold')
plt.yticks(fontweight='bold')

plt.xlabel("Year",fontweight='bold')
plt.ylabel("Total Crimes",fontweight='bold')
plt.title("Distribution of the total number of crimes over the years",fontweight='bold',fontsize=20)

ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)

bar= sns.barplot(x="Year", y=arr, palette="coolwarm", data=year_df)
for p in bar.patches:
    bar.annotate(format(p.get_height(), '.0f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 9), 
                   textcoords = 'offset points')

# %%
states_df["total_crime"]= states_df.sum(axis=1)
#states_df.drop("STATE/UT", axis=1)
new=states_df.sort_values("total_crime")
sns.set(rc={'figure.figsize':(17,10)})
ax=plt.axes()
new=new.reset_index()

plt.title("Statewise Distribution of Crime from 2001-2014",fontweight='bold',fontsize=20)
ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)
plt.ylabel("Total Crimes",fontweight='bold')
sns.barplot(x="STATE/UT", y="total_crime", palette="coolwarm", data=new)
# Out:
# <AxesSubplot:title={'center':'Statewise Distribution of Crime from 2001-2014'}, xlabel='STATE/UT', ylabel='total_crime'>

# %%
crimes=['Rape','Kidnapping and Abduction','Dowry Deaths',
        'Assault on women with intent to outrage her modesty',
        'Insult to modesty of Women','Cruelty by Husband or his Relatives',
        'Importation of Girls']

df_top_crimes=pd.DataFrame(columns=['crimes',"total"])

for i in crimes:
    df_top_crimes=df_top_crimes.append({'crimes':i ,'total':df[i].sum(axis=0)},ignore_index=True)
    
df_top_crimes=df_top_crimes.sort_values(by='total',ascending=False)

df_top_crimes

list_crimes_number=list(df_top_crimes['total'])
list_crimes=list(df_top_crimes['crimes'])
fig=plt.figure(figsize=(12,10))

ax=plt.axes()
colors = sns.color_palette('coolwarm',6)
plt.pie(list_crimes_number,labels=list_crimes,autopct='%1.2f%%', colors=colors,counterclock=False)

plt.title("Distribution of Crimes from 2001 to 2014",fontweight='bold',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Distribution of Crimes from 2001 to 2014')

# %%
f,(ax1,ax2)=plt.subplots(1,2)
f.set_figheight(12)
f.set_figwidth(12)

colors = sns.color_palette('coolwarm',8)
ax1.pie(year_df.iloc[0],autopct='%1.2f%%', colors=colors,radius=1.5, pctdistance=0.80, center=(1,0),counterclock=True)
ax1.text(0.1,1.7,"Crime Distrubution in 2001",fontweight='bold',fontsize=20)
ax2.pie(year_df.iloc[13],autopct='%1.2f%%', colors=colors,radius=1.5, pctdistance=0.80, center=(1,0),counterclock=True)
plt.text(0.1,1.7,"Crime Distrubution in 2014",fontweight='bold',fontsize=20)
plt.legend(loc="center", bbox_to_anchor=(0.5, -0.25), ncol= 2, labels=crimes)
f.tight_layout()
plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=1, 
                    top=1, 
                    wspace=0.5, 
                    hspace=0.5)

# %%
sns.set(rc={'figure.figsize':(17,10)})
colors = sns.color_palette('hls')
line_df=year_df
line_df=line_df.drop("Year", axis=1)
line_df.plot(color=colors, xlabel="YEAR", ylabel="Crime Rate", kind="line", fontsize=10,linewidth=3);
plt.title("Distribution of various crimes over the years", fontsize=20,fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Distribution of various crimes over the years')

# %%
transposed_df=year_df
transposed_df=transposed_df.transpose()
transposed_df["total_crime"]= transposed_df.sum(axis=1)
#transposed_df.drop("total_crime", axis=0)

temp_df=transposed_df["total_crime"]
colors = sns.color_palette('flare')

plt.ylabel("Total Crimes",fontweight='bold')
#plt.xlabel("Crime",fontweight='bold')
temp_df=temp_df.sort_values(ascending=False).drop("Year")
temp_df.plot(kind="bar", color=colors)
# Out:
# <AxesSubplot:ylabel='Total Crimes'>

# %% [markdown]
# # CRIME WISE ANALYSIS

# %% [markdown]
# Analysis of the top 4 crimes
# - Cruelty by Husband or his Relatives
# - Assault on women with intent to outrage her modesty
# - Kidnapping and Abduction
# - Rape

# %%
fig, axes = plt.subplots(2, 2, figsize=(18, 15))
  
fig.suptitle('Distribution of the top 4 crimes by year', fontsize=20)
sns.barplot(ax=axes[0, 0], data=year_df, x='Year', y='Cruelty by Husband or his Relatives',palette="Spectral")
sns.barplot(ax=axes[0, 1], data=year_df, x='Year', y='Assault on women with intent to outrage her modesty',palette="Spectral")  
sns.barplot(ax=axes[1, 0], data=year_df, x='Year', y='Kidnapping and Abduction',palette="Spectral")
sns.barplot(ax=axes[1, 1], data=year_df, x='Year', y='Rape',palette="Spectral")
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Rape'>

# %%
newstates_df=states_df
newstates_df.reset_index()
# Out:
#              STATE/UT   Rape  Kidnapping and Abduction  Dowry Deaths  \
# 0       a & n islands    168                       106            10
# 1      andhra pradesh  16075                     17252          6922
# 2   arunachal pradesh    658                       735             3
# 3               assam  20095                     31037          1634
# 4               bihar  15379                     28543         16103
# 5          chandigarh    385                       841            45
# 6        chhattisgarh  14654                      5904          1379
# 7        d & n haveli     66                       112             1
# 8         daman & diu     30                        22             3
# 9               delhi  10156                     23293          1879
# 10                goa    531                       320            19
# 11            gujarat   5822                     17335           554
# 12            haryana   8555                     10008          3686
# 13   himachal pradesh   2337                      2058            56
# 14    jammu & kashmir   3519                     10582           147
# 15          jharkhand  11413                      7093          3948
# 16          karnataka   7528                      8131          3508
# 17             kerala  10015                      2226           350
# 18        lakshadweep     10                         1             0
# 19     madhya pradesh  45498                     17804         10545
# 20        maharashtra  24487                     15184          4848
# 21            manipur    534                      1303             3
# 22          meghalaya   1321                       335            18
# 23            mizoram   1035                        15             4
# 24           nagaland    281                        95             1
# 25             odisha  15240                     12794          5391
# 26         puducherry    104                       153            28
# 27             punjab   7328                      7548          1762
# 28          rajasthan  22842                     33139          5927
# 29             sikkim    285                        90             2
# 30         tamil nadu   8330                     15454          2530
# 31          telangana    979                       711           289
# 32            tripura   2530                      1101           376
# 33      uttar pradesh  25575                     67953         28628
# 34        uttarakhand   1876                      3242           987
# 35        west bengal  23938                     30579          6154
#
#     Assault on women with intent to outrage her modesty  \
# 0                                                 300
# 1                                               63476
# 2                                                 998
# 3                                               19128
# 4                                                8479
# 5                                                 544
# 6                                               23548
# 7                                                  53
# 8                                                  20
# 9                                               15371
# 10                                                692
# 11                                              11593
# 12                                               8571
# 13                                               4628
# 14                                              14319
# 15                                               4949
# 16                                              32875
# 17                                              40219
# 18                                                  7
# 19                                              97739
# 20                                              57352
# 21                                                661
# 22                                                735
# 23                                                994
# 24                                                130
# 25                                              40107
# 26                                                657
# 27                                               6205
# 28                                              41681
# 29                                                293
# 30                                              21702
# 31                                               3188
# 32                                               3672
# 33                                              45606
# 34                                               2183
# 35                                              33454
#
#     Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# 0                           56                                  144
# 1                        43482                               140453
# 2                           24                                  238
# 3                          127                                57650
# 4                          347                                34885
# 5                          171                                 1040
# 6                         1984                                11718
# 7                            6                                   45
# 8                            2                                   38
# 9                         3964                                21417
# 10                         234                                  266
# 11                        1615                                73234
# 12                        8933                                34207
# 13                         610                                 3898
# 14                        4584                                 2695
# 15                         283                                11955
# 16                        1138                                36353
# 17                        3965                                55813
# 18                           2                                    7
# 19                       10482                                51408
# 20                       16317                                96601
# 21                           3                                  289
# 22                          62                                  230
# 23                          35                                   67
# 24                          12                                   16
# 25                        3744                                24603
# 26                         300                                  117
# 27                         864                                15420
# 28                         397                               131100
# 29                          17                                   54
# 30                       10585                                22762
# 31                        1142                                 6369
# 32                          57                                 8043
# 33                       26565                                96869
# 34                        1595                                 4878
# 35                        2674                               172062
#
#     Importation of Girls  total_crime
# 0                      0          784
# 1                     17       287677
# 2                      0         2656
# 3                     11       129682
# 4                    452       104188
# 5                      0         3026
# 6                      6        59193
# 7                      0          283
# 8                      0          115
# 9                      1        76081
# 10                     0         2062
# 11                     0       110153
# 12                     2        73962
# 13                     0        13587
# 14                     0        35846
# 15                   149        39790
# 16                    47        89580
# 17                     0       112588
# 18                     0           27
# 19                    67       233543
# 20                     3       214792
# 21                     0         2793
# 22                     4         2705
# 23                     3         2153
# 24                     1          536
# 25                    18       101897
# 26                     0         1359
# 27                     2        39129
# 28                     7       235093
# 29                     0          741
# 30                    15        81378
# 31                     0        12678
# 32                     0        15779
# 33                     3       291199
# 34                     1        14762
# 35                   127       268988

# %%
sns.set(rc={'figure.figsize':(15,11)})
ax=plt.axes()

plt.title("Distribution of 'Cruelty by Husband or Relatives' cases by state",fontweight='bold',fontsize=20)

ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)


cruelty_df=states_df["Cruelty by Husband or his Relatives"]


cruelty_df=cruelty_df.sort_values(ascending=False)
colors = sns.color_palette('mako_r',24)

cruelty_df.plot(kind="bar", color=colors, ylabel="Total Cases")
# Out:
# <AxesSubplot:title={'center':"Distribution of 'Cruelty by Husband or Relatives' cases by state"}, xlabel='STATE/UT', ylabel='Total Cases'>

# %%
sns.set(rc={'figure.figsize':(15,11)})
ax=plt.axes()

plt.title("Distribution of Rape cases by state",fontweight='bold',fontsize=20)

ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)


rape_df=states_df["Rape"]


rape_df=rape_df.sort_values(ascending=False)
colors = sns.color_palette('rocket_r',34)

rape_df.plot(kind="bar", color=colors, ylabel="Total Cases")
# Out:
# <AxesSubplot:title={'center':'Distribution of Rape cases by state'}, xlabel='STATE/UT', ylabel='Total Cases'>

# %%
sns.set(rc={'figure.figsize':(15,11)})
ax=plt.axes()

plt.title("Distribution of 'Assault on women with intent to outrage her modesty' cases by state",fontweight='bold',fontsize=20)

ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)


assault_df=states_df['Assault on women with intent to outrage her modesty']


assault_df=assault_df.sort_values(ascending=False)
colors = sns.color_palette('coolwarm',32)

assault_df.plot(kind="bar", color=colors, ylabel="Total Cases")
# Out:
# <AxesSubplot:title={'center':"Distribution of 'Assault on women with intent to outrage her modesty' cases by state"}, xlabel='STATE/UT', ylabel='Total Cases'>

# %%
sns.set(rc={'figure.figsize':(15,11)})
ax=plt.axes()

plt.title("Distribution of 'Kidnapping and Abduction' cases by state",fontweight='bold',fontsize=20)

ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)


kidnap_df=states_df['Kidnapping and Abduction']


kidnap_df=kidnap_df.sort_values(ascending=False)
colors = sns.color_palette('flare',26)

kidnap_df.plot(kind="bar", color=colors, ylabel="Total Cases")
# Out:
# <AxesSubplot:title={'center':"Distribution of 'Kidnapping and Abduction' cases by state"}, xlabel='STATE/UT', ylabel='Total Cases'>

# %% [markdown]
# # STATEWISE

# %% [markdown]
# Analysis of Top 3 states in terms of total crime
# - Uttar Pradesh
# - Andhra Pradesh
# - West Bengal

# %% [markdown]
# # UTTAR PRADESH

# %%
sortstates_df=states_df
sortstates_df=sortstates_df.sort_values("total_crime", ascending=False)

upcrime_df=sortstates_df.iloc[0]
upcrime_df=upcrime_df.drop("total_crime").sort_values(ascending=False)

# %%
colors = sns.color_palette('Set2')
upcrime=upcrime_df.plot(kind="bar",color=colors)
for p in upcrime.patches:
    upcrime.annotate(format(p.get_height(), '.0f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 9), 
                   textcoords = 'offset points')

# %%
up_df=df
up_df=up_df.drop("DISTRICT",axis=1)
up_df = up_df[(up_df['STATE/UT'] == 'uttar pradesh')]
up_df=up_df.groupby('Year')[['Rape','Kidnapping and Abduction','Dowry Deaths','Assault on women with intent to outrage her modesty','Insult to modesty of Women','Cruelty by Husband or his Relatives','Importation of Girls']].sum()
up_df["total_crime"]= up_df.sum(axis=1)
upyears_df=up_df
upyears_df=upyears_df.drop("total_crime",axis=1)

# %%
up_df=up_df.reset_index()

sns.barplot(data=up_df, x="Year", y="total_crime", palette="magma_r")
plt.title("Crime Distribution in Uttar Pradesh from 2001-2014", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Crime Distribution in Uttar Pradesh from 2001-2014')

# %%
upline_df=up_df
upline_df=upline_df.set_index("Year").drop("total_crime", axis=1)

# %%
colors=sns.color_palette("tab10")
upline_df.plot(kind="line", color=colors, linewidth=3)
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
f,(ax1,ax2)=plt.subplots(1,2)
f.set_figheight(12)
f.set_figwidth(12)

colors = sns.color_palette('coolwarm',6)
ax1.pie(upyears_df.iloc[0],autopct='%1.2f%%', colors=colors,radius=1.5, pctdistance=0.80, center=(1,0),counterclock=True)
ax1.text(0.1,1.7,"Crime Distrubution in 2001",fontweight='bold',fontsize=20)
ax2.pie(upyears_df.iloc[13],autopct='%1.2f%%', colors=colors,radius=1.5, pctdistance=0.80, center=(1,0),counterclock=True)
plt.text(0.1,1.7,"Crime Distrubution in 2014",fontweight='bold',fontsize=20)
plt.legend(loc="center", bbox_to_anchor=(0.5, -0.25), ncol= 2, labels=crimes)
f.tight_layout()
plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=1, 
                    top=1, 
                    wspace=0.5, 
                    hspace=0.5)

# %% [markdown]
# # ANDHRA PRADESH

# %%
apcrime_df=sortstates_df.iloc[1]
apcrime_df
# Out:
# Rape                                                    16075
# Kidnapping and Abduction                                17252
# Dowry Deaths                                             6922
# Assault on women with intent to outrage her modesty     63476
# Insult to modesty of Women                              43482
# Cruelty by Husband or his Relatives                    140453
# Importation of Girls                                       17
# total_crime                                            575354
# Name: andhra pradesh, dtype: int64

# %%
colors = sns.color_palette('Set2',7)

apcrime_df=apcrime_df.sort_values(ascending=False)
apcrime_df=apcrime_df.drop("total_crime")
apcrime=apcrime_df.plot(kind="bar",color=colors)

for p in apcrime.patches:
    apcrime.annotate(format(p.get_height(), '.0f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 9), 
                   textcoords = 'offset points')

# %%
ap_df=df
ap_df=ap_df.drop("DISTRICT",axis=1)
ap_df = ap_df[(ap_df['STATE/UT'] == 'andhra pradesh')]
ap_df=ap_df.groupby('Year')[['Rape','Kidnapping and Abduction','Dowry Deaths','Assault on women with intent to outrage her modesty','Insult to modesty of Women','Cruelty by Husband or his Relatives','Importation of Girls']].sum()
ap_df["total_crime"]= ap_df.sum(axis=1)
apyears_df=ap_df
apyears_df=apyears_df.drop("total_crime",axis=1)

# %%
ap_df=ap_df.reset_index()

sns.barplot(data=ap_df, x="Year", y="total_crime", palette="magma_r")
plt.title("Crime Distribution in Andhra Pradesh from 2001-2014", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Crime Distribution in Andhra Pradesh from 2001-2014')

# %%
apline_df=ap_df
apline_df=apline_df.set_index("Year").drop("total_crime", axis=1)

# %%
colors=sns.color_palette("tab10")
apline_df.plot(kind="line", color=colors, linewidth=3)
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
f,(ax1,ax2)=plt.subplots(1,2)
f.set_figheight(12)
f.set_figwidth(12)


colors = sns.color_palette('coolwarm',6)
ax1.pie(apyears_df.iloc[0],autopct='%1.2f%%', colors=colors,radius=1.5, pctdistance=0.80, center=(1,0),counterclock=True)
ax1.text(0.1,1.7,"Crime Distrubution in 2001",fontweight='bold',fontsize=25)
ax2.pie(apyears_df.iloc[13],autopct='%1.2f%%', colors=colors,radius=1.5, pctdistance=0.80, center=(1,0),counterclock=True)
plt.text(0.1,1.7,"Crime Distrubution in 2014",fontweight='bold',fontsize=25)
plt.legend(loc="center", bbox_to_anchor=(0.5, -0.25), ncol= 2, labels=crimes)
f.tight_layout()
plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=1, 
                    top=1, 
                    wspace=0.5, 
                    hspace=0.5)

# %% [markdown]
# # WEST BENGAL

# %%
wbcrime_df=sortstates_df.iloc[2]

wbcrime_df=wbcrime_df.drop("total_crime")

# %%
colors = sns.color_palette('Set2',7)

wbcrime_df=wbcrime_df.sort_values(ascending=False)

wbcrime=wbcrime_df.plot(kind="bar",color=colors)

for p in wbcrime.patches:
    wbcrime.annotate(format(p.get_height(), '.0f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 9), 
                   textcoords = 'offset points')

# %%
wb_df=df
wb_df=wb_df.drop("DISTRICT",axis=1)
wb_df = wb_df[(wb_df['STATE/UT'] == 'west bengal')]
wb_df=wb_df.groupby('Year')[['Rape','Kidnapping and Abduction','Dowry Deaths','Assault on women with intent to outrage her modesty','Insult to modesty of Women','Cruelty by Husband or his Relatives','Importation of Girls']].sum()
wb_df["total_crime"]= wb_df.sum(axis=1)
wbyears_df=wb_df
wbyears_df=wbyears_df.drop("total_crime",axis=1)

# %%
wb_df=wb_df.reset_index()

sns.barplot(data=wb_df, x="Year", y="total_crime", palette="magma_r")
plt.title("Crime Distribution in Andhra Pradesh from 2001-2014", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Crime Distribution in Andhra Pradesh from 2001-2014')

# %%
wbline_df=wb_df
wbline_df=wbline_df.set_index("Year").drop("total_crime", axis=1)

# %%
colors=sns.color_palette("tab10")
wbline_df.plot(kind="line", color=colors, linewidth=3)
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
f,(ax1,ax2)=plt.subplots(1,2)
f.set_figheight(12)
f.set_figwidth(12)


colors = sns.color_palette('coolwarm',6)
ax1.pie(wbyears_df.iloc[0],autopct='%1.2f%%', colors=colors,radius=1.5, pctdistance=0.80, center=(1,0),counterclock=True)
ax1.text(0.1,1.7,"Crime Distrubution in 2001",fontweight='bold',fontsize=25)
ax2.pie(wbyears_df.iloc[13],autopct='%1.2f%%', colors=colors,radius=1.5, pctdistance=0.80, center=(1,0),counterclock=True)
plt.text(0.1,1.7,"Crime Distrubution in 2014",fontweight='bold',fontsize=25)
plt.legend(loc="center", bbox_to_anchor=(0.5, -0.25), ncol= 2, labels=crimes)
f.tight_layout()
plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=1, 
                    top=1, 
                    wspace=0.5, 
                    hspace=0.5)
